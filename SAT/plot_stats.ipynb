# %% [markdown]
# # Plot STATS

# %%
import os
import json
import matplotlib.pyplot as plt

# %%
BASE_DIR = "../res/SAT"  

def load_results_flat(base_dir=BASE_DIR):
    all_data = {}  # {n: {model: metrics}}
    for fname in sorted(os.listdir(base_dir)):
        if fname.endswith(".json"):
            n_part = os.path.splitext(fname)[0]
            try:
                n = int(n_part)
            except ValueError:
                continue
            json_path = os.path.join(base_dir, fname)
            with open(json_path, "r") as f:
                data = json.load(f)
                
                filtered_data = {
                    model_name: metrics
                    for model_name, metrics in data.items()
                    if not model_name.startswith("decisional")
                }
                
                if filtered_data:
                    all_data[n] = filtered_data
    return all_data

all_data = load_results_flat()
print(all_data)
# Out:
# {10: {'optimization_heule_seq_sb': {'time': 0, 'optimal': True, 'obj': 1, 'sol': [[[1, 10], [7, 6], [8, 7], [4, 10], [2, 8], [9, 3], [5, 9], [5, 2], [3, 6]], [[2, 9], [9, 4], [1, 5], [7, 1], [10, 5], [10, 6], [6, 8], [4, 3], [2, 7]], [[3, 8], [10, 2], [9, 6], [5, 3], [4, 6], [5, 7], [1, 4], [9, 7], [1, 8]], [[7, 4], [8, 5], [10, 3], [6, 2], [1, 9], [4, 8], [3, 2], [6, 1], [10, 9]], [[6, 5], [3, 1], [4, 2], [8, 9], [3, 7], [2, 1], [7, 10], [8, 10], [5, 4]]], 'max_diff': 0, 'restarts': 0, 'conflicts': 787, 'mk_bool_var': 2875, 'max_memory': 22.23}, 'optimization_heule_seq_no_sb': {'time': 0, 'optimal': True, 'obj': 1, 'sol': [[[4, 7], [5, 8], [10, 3], [9, 8], [4, 6], [2, 1], [5, 9], [1, 6], [7, 2]], [[1, 10], [6, 7], [9, 6], [3, 5], [9, 1], [8, 4], [2, 3], [8, 10], [5, 4]], [[3, 8], [4, 9], [1, 5], [6, 2], [7, 3], [6, 10], [10, 7], [5, 2], [8, 1]], [[2, 9], [3, 1], [4, 2], [4, 10], [10, 5], [5, 7], [6, 8], [9, 7], [3, 6]], [[6, 5], [2, 10], [7, 8], [7, 1], [8, 2], [9, 3], [1, 4], [3, 4], [10, 9]]], 'max_diff': 0, 'restarts': 0, 'conflicts': 448, 'mk_bool_var': 3380, 'max_memory': 23.13}, 'optimization_np-np_sb': {'time': 0, 'optimal': True, 'obj': 1, 'sol': [[[1, 10], [10, 2], [2, 4], [5, 3], [4, 6], [3, 9], [6, 8], [9, 7], [1, 8]], [[2, 9], [5, 8], [10, 3], [4, 10], [3, 7], [4, 8], [9, 5], [6, 1], [2, 7]], [[8, 3], [7, 6], [1, 5], [2, 6], [8, 2], [5, 7], [1, 4], [4, 3], [9, 10]], [[7, 4], [3, 1], [6, 9], [8, 9], [10, 5], [2, 1], [10, 7], [5, 2], [3, 6]], [[5, 6], [9, 4], [7, 8], [7, 1], [1, 9], [6, 10], [3, 2], [8, 10], [4, 5]]], 'max_diff': 0, 'restarts': 0, 'conflicts': 1124, 'mk_bool_var': 2875, 'max_memory': 21.93}, 'optimization_np-np_no_sb': {'time': 0, 'optimal': True, 'obj': 1, 'sol': [[[5, 6], [3, 1], [2, 4], [2, 6], [7, 3], [5, 7], [4, 1], [10, 8], [9, 10]], [[9, 2], [10, 2], [7, 8], [1, 7], [1, 9], [6, 10], [6, 8], [3, 4], [4, 5]], [[8, 3], [9, 4], [5, 1], [8, 9], [6, 4], [1, 2], [10, 7], [2, 5], [6, 3]], [[4, 7], [8, 5], [3, 10], [4, 10], [2, 8], [3, 9], [5, 9], [6, 1], [2, 7]], [[1, 10], [7, 6], [9, 6], [5, 3], [10, 5], [4, 8], [3, 2], [7, 9], [8, 1]]], 'max_diff': 0, 'restarts': 0, 'conflicts': 206, 'mk_bool_var': 3380, 'max_memory': 190.01}, 'optimization_heule_totalizer_sb': {'time': 0, 'optimal': True, 'obj': 1, 'sol': [[[1, 10], [8, 5], [9, 6], [7, 1], [8, 2], [6, 10], [3, 2], [4, 3], [5, 4]], [[2, 9], [3, 1], [3, 10], [4, 10], [6, 4], [5, 7], [8, 6], [9, 7], [1, 8]], [[3, 8], [7, 6], [4, 2], [5, 3], [1, 9], [4, 8], [10, 7], [5, 2], [10, 9]], [[7, 4], [4, 9], [1, 5], [2, 6], [3, 7], [2, 1], [9, 5], [10, 8], [6, 3]], [[6, 5], [10, 2], [7, 8], [8, 9], [5, 10], [9, 3], [1, 4], [6, 1], [2, 7]]], 'max_diff': 0, 'restarts': 0, 'conflicts': 218, 'mk_bool_var': 2925, 'max_memory': 23.25}, 'optimization_heule_totalizer_no_sb': {'time': 0, 'optimal': True, 'obj': 1, 'sol': [[[1, 10], [6, 7], [3, 10], [1, 7], [2, 8], [4, 8], [5, 9], [5, 2], [6, 3]], [[8, 3], [9, 4], [8, 7], [2, 6], [10, 5], [7, 5], [4, 1], [1, 6], [10, 9]], [[4, 7], [8, 5], [5, 1], [9, 8], [9, 1], [10, 6], [3, 2], [4, 3], [7, 2]], [[6, 5], [2, 10], [4, 2], [10, 4], [3, 7], [3, 9], [8, 6], [7, 9], [1, 8]], [[9, 2], [3, 1], [9, 6], [5, 3], [6, 4], [2, 1], [7, 10], [8, 10], [5, 4]]], 'max_diff': 0, 'restarts': 0, 'conflicts': 363, 'mk_bool_var': 3430, 'max_memory': 219.51}}, 12: {'optimization_heule_seq_sb': {'time': 1, 'optimal': True, 'obj': 1, 'sol': [[[1, 12], [9, 6], [6, 11], [4, 12], [7, 3], [10, 2], [10, 4], [9, 7], [5, 2], [8, 1], [8, 3]], [[11, 2], [2, 12], [10, 7], [11, 8], [1, 9], [5, 7], [8, 6], [4, 1], [3, 4], [12, 10], [6, 5]], [[3, 10], [7, 8], [3, 12], [2, 6], [6, 4], [11, 1], [5, 9], [11, 5], [9, 12], [2, 7], [1, 10]], [[4, 9], [5, 10], [1, 5], [9, 10], [8, 2], [12, 6], [11, 3], [12, 8], [11, 7], [6, 3], [7, 4]], [[5, 8], [3, 1], [4, 2], [3, 5], [10, 11], [8, 4], [12, 7], [6, 10], [1, 6], [9, 11], [2, 9]], [[7, 6], [4, 11], [9, 8], [7, 1], [5, 12], [3, 9], [1, 2], [2, 3], [10, 8], [4, 5], [12, 11]]], 'max_diff': 0, 'restarts': 0, 'conflicts ...

# %%
def plot_metric(all_data, metric, ylabel, title, log_y=False):
    """
    Plots a metric for various models and team counts.

    The function distinguishes between data points where a solution
    was found (obj is not None) and those where it wasn't (obj is None).
    - A star (*) marker indicates a sub-optimal or optimal solution was found.
    - A dot (.) marker indicates no solution was found.

    Args:
        all_data (dict): A nested dictionary with the structure {n: {model: metrics}}.
        metric (str): The specific metric to plot (e.g., 'runtime', 'obj').
        ylabel (str): The label for the y-axis.
        title (str): The title of the plot.
        log_y (bool): If True, the y-axis will be in a logarithmic scale.
    """
    plt.figure(figsize=(8, 5))
    models = sorted({m for data in all_data.values() for m in data.keys()})


    num_models = len(models)
    offset_step = 0.15 
    base_offset = - (num_models - 1) * offset_step / 2

    for i, model in enumerate(models):
        model_offset = base_offset + i * offset_step
        
        ns_with_obj = []
        values_with_obj = []
        ns_without_obj = []
        values_without_obj = []
        
        ns_all = []
        values_all = []

        for n in sorted(all_data.keys()):
            data = all_data[n].get(model)
            if data and data.get(metric) is not None:
                val = data.get(metric)
                ns_all.append(n)
                values_all.append(val)
                

                if data.get('obj') is not None:
                    ns_with_obj.append(n)
                    values_with_obj.append(val)
                else:
                    ns_without_obj.append(n)
                    values_without_obj.append(val)
        
        if ns_all:
            line, = plt.plot(ns_all, values_all, linestyle='-', label=model)
            color = line.get_color()
            
            if ns_with_obj:
                ns_with_obj_offset = [n + model_offset for n in ns_with_obj]
                plt.plot(ns_with_obj_offset, values_with_obj, marker='*', linestyle='', color=color, markersize=10)
            if ns_without_obj:
                ns_without_obj_offset = [n + model_offset for n in ns_without_obj]
                plt.plot(ns_without_obj_offset, values_without_obj, marker='.', linestyle='', color=color, markersize=10)
                
    plt.xlabel("Number of Teams (n)")
    plt.ylabel(ylabel)
    plt.title(title)
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    if log_y:
        plt.yscale("log")
    plt.xticks(sorted(all_data.keys()))  
    plt.show()

# %%
plot_metric(
    all_data,
    metric="time",
    ylabel="Solve Time (s)",
    title="Resolution time for each model"
)

# %%
def plot_metric(all_data, metric, ylabel, title, log_y=False):
    plt.figure(figsize=(8, 5))
    models = sorted({m for data in all_data.values() for m in data.keys()})

    for model in models:
        ns = []
        values = []
        for n in sorted(all_data.keys()): # all_data = {n: {model: metrics}}
            data = all_data[n].get(model)
            val = data.get(metric) if data else None
            if val is not None:
                ns.append(n)
                values.append(val)
        if ns:
            plt.plot(ns, values, marker='o', label=model)
    plt.xlabel("Number of Teams (n)")
    plt.ylabel(ylabel)
    plt.title(title)
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    if log_y:
        plt.yscale("log")
    plt.xticks(sorted(all_data.keys()))  
    plt.show()

# %%
plot_metric(
    all_data,
    metric="conflicts",
    ylabel="Conflicts",
    title="Number of conflicts for each model"
)

plot_metric(
    all_data,
    metric="mk_bool_var",
    ylabel="Boole Vars Created",
    title="Boolean variable created for each model"
)

plot_metric(
    all_data,
    metric="max_memory",
    ylabel="Max Memory required",
    title="Maximum Memory required for each model (MB)"
)

# %% [markdown]
# -------------------

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_metric_2(all_data, metric, ylabel, title, log_y=False):
    """
    Plots a metric for various models and team counts.

    The function distinguishes between data points where a solution
    was found (obj is not None) and those where it wasn't (obj is None).
    - A star (*) marker indicates a sub-optimal or optimal solution was found.
    - A dot (.) marker indicates no solution was found.

    Args:
        all_data (dict): A nested dictionary with the structure {n: {model: metrics}}.
        metric (str): The specific metric to plot (e.g., 'runtime', 'obj').
        ylabel (str): The label for the y-axis.
        title (str): The title of the plot.
        log_y (bool): If True, the y-axis will be in a logarithmic scale.
    """
    plt.figure(figsize=(8, 5))
    models = sorted({m for data in all_data.values() for m in data.keys()})

    num_models = len(models)
    offset_step = 0.15
    base_offset = - (num_models - 1) * offset_step / 2

    for i, model in enumerate(models):
        model_offset = base_offset + i * offset_step

        ns_with_obj = []
        values_with_obj = []
        ns_without_obj = []
        values_without_obj = []

        ns_all = []
        values_all = []

        for n in sorted(all_data.keys()):
            data = all_data[n].get(model)
            if data and data.get(metric) is not None:
                val = data.get(metric)
                
                # Sostituisce i valori a zero con un numero molto piccolo
                if val == 0:
                    val = 1e-9  # Un valore molto piccolo per la scala logaritmica
                
                ns_all.append(n)
                values_all.append(val)

                if data.get('obj') is not None:
                    ns_with_obj.append(n)
                    values_with_obj.append(val)
                else:
                    ns_without_obj.append(n)
                    values_without_obj.append(val)

        if ns_all:
            ns_all_offset = [n + model_offset for n in ns_all]
            line, = plt.plot(ns_all_offset, values_all, linestyle='-', label=model)
            color = line.get_color()

            if ns_with_obj:
                ns_with_obj_offset = [n + model_offset for n in ns_with_obj]
                plt.plot(ns_with_obj_offset, values_with_obj, marker='*', linestyle='', color=color, markersize=10)
            if ns_without_obj:
                ns_without_obj_offset = [n + model_offset for n in ns_without_obj]
                plt.plot(ns_without_obj_offset, values_without_obj, marker='.', linestyle='', color=color, markersize=10)

    plt.xlabel("Number of Teams (n)")
    plt.ylabel(ylabel)
    plt.title(title)
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    if log_y:
        plt.yscale("log")
    plt.xticks(sorted(all_data.keys()))
    plt.show()

# %%
# Chiamata alla funzione con i tuoi dati
plot_metric_2(
    all_data,
    metric='time',
    ylabel='Execution Time (s)',
    title='Execution Time vs. Number of Teams',
    log_y=True
)
